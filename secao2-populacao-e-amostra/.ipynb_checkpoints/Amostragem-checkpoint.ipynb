# %% [markdown]
# # População e amostra

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import random
import numpy as np

# %% [markdown]
# ### Leitura de dados

# %%
# Input data
path_file = r"../data/raw_data/census.csv"
dataset = pd.read_csv(path_file, sep=',', encoding='utf8')
print("Base de dados")
print(f'Dimensão: {dataset.shape[0]} linhas e {dataset.shape[1]} colunas')
dataset.sample(n=5)
# Out:
# Base de dados
# Dimensão: 32561 linhas e 15 colunas
#        age workclass  final-weight      education  education-num  \
# 3121    21   Private        155066   Some-college             10
# 9891    30   Private        241583   Some-college             10
# 25999   37   Private        205339        HS-grad              9
# 16704   19   Private        252862      Assoc-voc             11
# 10785   45   Private        242994   Some-college             10
#
#             marital-status          occupation    relationship    race  \
# 3121         Never-married        Craft-repair       Own-child   White
# 9891    Married-civ-spouse   Machine-op-inspct         Husband   White
# 25999             Divorced        Craft-repair   Not-in-family   White
# 16704        Never-married      Prof-specialty       Own-child   White
# 10785        Never-married               Sales   Not-in-family   White
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 3121      Male             0             0             40   United-States
# 9891      Male             0             0             40   United-States
# 25999     Male             0             0             49   United-States
# 16704   Female             0             0             40   United-States
# 10785     Male             0             0             52   United-States
#
#        income
# 3121    <=50K
# 9891    <=50K
# 25999   <=50K
# 16704   <=50K
# 10785   <=50K

# %% [markdown]
# ## Amostragem simples

# %%
# Functions
def amostragem_simples(dataset, samples):
    """ Return a simple random sample """
    return dataset.sample(n = samples, random_state=42)

# %%
df_amostra_simples = amostragem_simples(dataset, 100)

print("Linhas e colunas")
print(df_amostra_simples.shape)
df_amostra_simples.head()
# Out:
# Linhas e colunas
# (100, 15)
#        age          workclass  final-weight      education  education-num  \
# 14160   27            Private        160178   Some-college             10
# 27048   45          State-gov         50567        HS-grad              9
# 28868   29            Private        185908      Bachelors             13
# 5667    30            Private        190040      Bachelors             13
# 7827    29   Self-emp-not-inc        189346   Some-college             10
#
#             marital-status          occupation    relationship    race  \
# 14160             Divorced        Adm-clerical   Not-in-family   White
# 27048   Married-civ-spouse     Exec-managerial            Wife   White
# 28868   Married-civ-spouse     Exec-managerial         Husband   Black
# 5667         Never-married   Machine-op-inspct   Not-in-family   White
# 7827              Divorced        Craft-repair   Not-in-family   White
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 14160   Female             0             0             38   United-States
# 27048   Female             0             0             40   United-States
# 28868     Male             0             0             55   United-States
# 5667    Female             0             0             40   United-States
# 7827      Male          2202             0             50   United-States
#
#        income
# 14160   <=50K
# 27048   <=50K
# 28868    >50K
# 5667    <=50K
# 7827    <=50K

# %% [markdown]
# ## Amostragem sistemática

# %%
def amostragem_sistematica(dataset, amostras):
    """Returna uma amostra sistemática"""
    intervalo = len(dataset) // amostras
    random.seed(1)
    inicio = random.randint(0, intervalo)
    indices = np.arange(inicio, len(dataset), step=intervalo)
    amostra_sistematica = dataset.iloc[indices]
    return amostra_sistematica

# %%
# Amostra sistemática
df_amostra_sistematica = amostragem_sistematica(dataset, 100)

print("Linhas e colunas")
print(df_amostra_sistematica.shape)
df_amostra_sistematica.head()
# Out:
# Linhas e colunas
# (100, 15)
#       age      workclass  final-weight      education  education-num  \
# 68     49   Self-emp-inc        191681   Some-college             10
# 393    34      State-gov         98101      Bachelors             13
# 718    22        Private        214399   Some-college             10
# 1043   44        Private        167005      Bachelors             13
# 1368   52        Private        152234        HS-grad              9
#
#            marital-status        occupation relationship                 race  \
# 68     Married-civ-spouse   Exec-managerial      Husband                White
# 393    Married-civ-spouse   Exec-managerial      Husband                White
# 718         Never-married             Sales    Own-child                White
# 1043   Married-civ-spouse   Exec-managerial      Husband                White
# 1368   Married-civ-spouse   Exec-managerial      Husband   Asian-Pac-Islander
#
#           sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 68       Male             0             0             50   United-States
# 393      Male          7688             0             45               ?
# 718    Female             0             0             15   United-States
# 1043     Male          7688             0             60   United-States
# 1368     Male         99999             0             40           Japan
#
#       income
# 68      >50K
# 393     >50K
# 718    <=50K
# 1043    >50K
# 1368    >50K

# %% [markdown]
# ## Amostragem por agrupamento

# %%
def amostragem_agrupamento(dataset, numero_grupos):
    intervalo = len(dataset) // numero_grupos
    grupos = []
    id_grupo = 0
    contagem = 0

    for _ in dataset.iterrows():
        grupos.append(id_grupo)
        contagem += 1
        if contagem > intervalo:
            contagem = 0
            id_grupo += 1

    dataset['grupo'] = grupos
    random.seed(1)
    grupo_selecionado = random.randint(0, numero_grupos)
    return dataset[dataset['grupo'] == grupo_selecionado]

# %%
# Amostra por grupos
df_amostra_agrupamento = amostragem_agrupamento(dataset, 100)
print("\nAmostra agrupamento")
print(f'Dimensão: {df_amostra_agrupamento.shape[0]} linhas e {df_amostra_agrupamento.shape[1]} colunas')
df_amostra_agrupamento.head()
# Out:
# Amostra agrupamento
# Dimensão: 326 linhas e 16 colunas
#       age          workclass  final-weight      education  education-num  \
# 5542   40       Self-emp-inc        169878     Assoc-acdm             12
# 5543   44            Private        296728        Masters             14
# 5544   33          Local-gov        342458     Assoc-acdm             12
# 5545   21          Local-gov         38771   Some-college             10
# 5546   35   Self-emp-not-inc        269300      Bachelors             13
#
#            marital-status        occupation    relationship    race      sex  \
# 5542   Married-civ-spouse   Exec-managerial            Wife   White   Female
# 5543   Married-civ-spouse   Exec-managerial         Husband   White     Male
# 5544             Divorced   Protective-serv   Not-in-family   White     Male
# 5545        Never-married      Adm-clerical       Own-child   White     Male
# 5546        Never-married     Other-service   Not-in-family   Black   Female
#
#       capital-gain  capital-loos  hour-per-week  native-country  income  grupo
# 5542             0             0             40   United-States    >50K     17
# 5543             0             0             40   United-States    >50K     17
# 5544             0             0             56   United-States   <=50K     17
# 5545             0             0             40   United-States   <=50K     17
# 5546             0             0             60   United-States   <=50K     17

# %% [markdown]
# ## Amostragem estratificada
#
# O objetivo é obter uma amostra que se respeite a proporção entre os elementos. Por exemplo, numa população de 90 pessoas, com 54 mulheres e 36 homens, se queremos uma amostra de 10%, teremos que selecionar proporcionalmente os 9 elementos

# %%
from sklearn.model_selection import StratifiedShuffleSplit

def amostragem_estratificada(dataset, tamanho_amostra):
    # Calcula o tamanho da amostra relativo ao total do dataset
    test_size = tamanho_amostra / len(dataset)
    random_state = 1
    
    # Configura o split para realizar uma divisão estratificada
    split = StratifiedShuffleSplit(n_splits=1, test_size=test_size, random_state=42)
    
    # Realiza o split
    for train_index, test_index in split.split(dataset, dataset['income']):
        df_amostra_estratificada = dataset.iloc[test_index]
    
    return df_amostra_estratificada

# %%
# Exemplo de uso
df_amostra_estratificada = amostragem_estratificada(dataset, 100)
print("\nAmostra estratificada")
print(f'Dimensão: {df_amostra_estratificada.shape[0]} linhas e {df_amostra_estratificada.shape[1]} colunas')
df_amostra_estratificada.head()
# Out:
# Amostra estratificada
# Dimensão: 100 linhas e 16 colunas
#        age workclass  final-weight      education  education-num  \
# 15955   51   Private        392286        HS-grad              9
# 19059   53   Private        132304        HS-grad              9
# 26608   60   Private        166330        HS-grad              9
# 20737   56   Private        274475            9th              5
# 26493   51   Private        137815   Some-college             10
#
#             marital-status          occupation    relationship    race  \
# 15955   Married-civ-spouse    Transport-moving         Husband   White
# 19059             Divorced   Machine-op-inspct   Not-in-family   White
# 26608   Married-civ-spouse        Adm-clerical            Wife   White
# 20737              Widowed               Sales       Unmarried   White
# 26493   Married-civ-spouse        Adm-clerical         Husband   White
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 15955     Male             0             0             40   United-States
# 19059   Female             0             0             40        Scotland
# 26608   Female             0             0             40   United-States
# 20737   Female             0             0             40   United-States
# 26493     Male          7298             0             40   United-States
#
#        income  grupo
# 15955    >50K     48
# 19059   <=50K     58
# 26608   <=50K     81
# 20737   <=50K     63
# 26493    >50K     81

# %%
df_amostra_estratificada['income'].value_counts()
# Out:
# income
# <=50K    76
# >50K     24
# Name: count, dtype: int64

# %% [markdown]
# ## Amostragem de reservatório
#
# Esta técnica é aplicada a _data stream_. Sortear itens num stream. Mas eles deve ter a mesma probabilidade.

# %%
def amostragem_reservatorio(dataset, amostras):
    stream = []
    tamanho = len(dataset)
    reservatorio = [0]*amostras
    
    for i in range(tamanho):
        stream.append(i)

    i = 0
    for i in range(amostras):
        reservatorio[i] = stream[i]

    
    while i < tamanho:
        j = random.randrange(i + 1)
        if j < amostras:
            reservatorio[j] = stream[i]
        i += 1
    
    return dataset.iloc[reservatorio]

# %%
df_amostragem_reservatorio = amostragem_reservatorio(dataset, 100)
df_amostragem_reservatorio.shape
# Out:
# (100, 16)

# %%
df_amostragem_reservatorio.head()
# Out:
#        age      workclass  final-weight     education  education-num  \
# 29608   41   Self-emp-inc        114580   Prof-school             15
# 21696   37    Federal-gov        329088       HS-grad              9
# 30676   42        Private        355728     Assoc-voc             11
# 28550   43        Private        110970     Bachelors             13
# 8768    52    Federal-gov        221532     Bachelors             13
#
#             marital-status        occupation    relationship    race      sex  \
# 29608   Married-civ-spouse   Exec-managerial            Wife   White   Female
# 21696   Married-civ-spouse      Adm-clerical         Husband   Black     Male
# 30676        Never-married      Craft-repair   Not-in-family   White     Male
# 28550   Married-civ-spouse    Prof-specialty         Husband   White     Male
# 8768    Married-civ-spouse   Protective-serv         Husband   White     Male
#
#        capital-gain  capital-loos  hour-per-week  native-country  income  \
# 29608             0          2415             55   United-States    >50K
# 21696             0             0             40   United-States   <=50K
# 30676             0             0             44   United-States   <=50K
# 28550             0          1902             40   United-States    >50K
# 8768              0             0             45   United-States    >50K
#
#        grupo
# 29608     90
# 21696     66
# 30676     94
# 28550     87
# 8768      26

# %% [markdown]
# ## Comparativo de amostragem

# %%
dataset['age'].mean()
# Out:
# 38.58164675532078

# %%
df_amostra_simples['age'].mean()
# Out:
# 38.32

# %%
df_amostra_sistematica['age'].mean()
# Out:
# 37.57

# %%
df_amostra_agrupamento['age'].mean()
# Out:
# 39.23312883435583

# %%
df_amostra_estratificada['age'].mean()
# Out:
# 39.37

# %%
df_amostragem_reservatorio['age'].mean()
# Out:
# 37.85
